# %% [markdown]
# # Analyse deposit event based profit calculation issue in
#
# See https://github.com/tradingstrategy-ai/trade-executor/issues/667

# %%
from tradeexecutor.utils.state_downloader import download_state
import os

name = "polygon-multipair-momentum.json"
url = "https://polygon-multipair-momentum.tradingstrategy.ai"
#url = "https://enzyme-polygon-multipair.tradingstrategy.ai"
#name = "enzyme-polygon-multipair"
if not os.path.exists(f"/tmp/{name}"):
    state = download_state(url)
    state.write_json_file(f"/tmp/{name}")

# %%
from tradeexecutor.state.state import State

state = State.read_json_file(f"/tmp/{name}")

# %% [markdown]
# ## Balance checks
#
# Check for current balances and abnormal balance update events.

# %%
portfolio = state.portfolio
asset, exchange_rate = state.portfolio.get_default_reserve_asset()
position = portfolio.get_default_reserve_position()
print(f"Number of reserve assets: {len(portfolio.reserves)}")
print(f"Reserves: {asset} at {exchange_rate} {asset.token_symbol} / USD")
print(f"Amount: {position.get_quantity()} {asset.token_symbol}")
print(f"Equity: {position.get_total_equity()} USD")
print(f"Value: {position.get_value()} USD")
print(f"Balance updates: {position.get_base_token_balance_update_quantity()} {asset.token_symbol}")
print(f"Number of balance updates events: {len(position.balance_updates)}")
print(f"Number of events references in the portfolio overall: {len(state.sync.treasury.balance_update_refs)}")
# Out:
# Number of reserve assets: 1
# Reserves: <USDC at 0x2791bca1f2de4661ed88a30c99a7a9449aa84174> at 1.0 USDC / USD
# Amount: 71.875852 USDC
# Equity: 71.875852 USD
# Value: 71.875852 USD
# Balance updates: 895131.464809 USDC
# Number of balance updates events: 12193
# Number of events references in the portfolio overall: 0

# %% [markdown]
# # Vault sync status

# %%
treasury = state.sync.treasury
deployment = state.sync.deployment

print(f"Vault deployment: {deployment}")
print(f"Treasury sync status: {treasury}")
# Out:
# Vault deployment: <Deployment chain:polygon address:0x8C95f9BB3bD2971Dd7D8F25D4F5D98e937A82F36 name:None token:None>
# Treasury sync status: <Treasury updated:2023-12-13 18:57:01 cycle:2023-12-13 18:57:00 block scanned:51,093,617 refs:0>

# %% [markdown]
# ## Individual events
#
# For the last analysed executor.

# %%
from pprint import pprint

events = list(position.get_balance_update_events())
print(f"Total {len(events)} balance update events")
# Out:
# Total 12193 balance update events

# %%
last_events = events[-100:]
for e in last_events:
    print(e)
    print(pprint(e.to_dict()))
# Out:
# Funding event #18177 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18177,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 13, 27),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 13, 27, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 13, 27),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18178 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18178,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 13, 30),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 13, 30, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 13, 30),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18179 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18179,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 13, 33),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 13, 33, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 13, 33),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18180 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18180,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 13, 36),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 13, 36, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 13, 36),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18181 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18181,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 13, 39),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 13, 39, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 13, 39),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18182 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18182,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 13, 42),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 13, 42, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 13, 42),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18183 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18183,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 13, 45),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 13, 45, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 13, 45),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18184 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18184,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 13, 48),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 13, 48, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 13, 48),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18185 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18185,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 13, 51),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 13, 51, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 13, 51),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18186 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18186,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 13, 54),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 13, 54, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 13, 54),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18187 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18187,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 13, 57),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 13, 57, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 13, 57),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18188 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18188,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 14, 0),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 14, 7, 59),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 14, 0),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18189 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18189,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 14, 9),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 14, 9, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 14, 9),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18190 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18190,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 14, 12),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 14, 12, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 14, 12),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18191 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18191,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 14, 15),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 14, 15, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 14, 15),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18192 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18192,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 14, 16, 52),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 14, 16, 53),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 14, 16, 52),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18193 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18193,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 14, 18),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 14, 18, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 14, 18),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18194 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18194,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 14, 21),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 14, 21, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 14, 21),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18195 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18195,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 14, 24),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 14, 24, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 14, 24),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18196 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18196,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 14, 27),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 14, 27, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 14, 27),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18197 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18197,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 14, 30),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 14, 30, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 14, 30),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18198 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18198,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 14, 33),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 14, 33, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 14, 33),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18199 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18199,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 14, 36),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 14, 36, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 14, 36),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18200 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18200,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 14, 39),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 14, 39, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 14, 39),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18201 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18201,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 14, 42),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 14, 42, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 14, 42),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18202 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18202,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 14, 45),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 14, 45, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 14, 45),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18203 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18203,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 14, 48),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 14, 48, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 14, 48),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18204 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18204,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 14, 51),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 14, 51, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 14, 51),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18205 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18205,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 14, 54),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 14, 54, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 14, 54),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18206 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18206,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 14, 57),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 14, 57, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 14, 57),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18207 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18207,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 15, 0),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 15, 8, 5),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 15, 0),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18208 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18208,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 15, 9),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 15, 9, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 15, 9),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18209 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18209,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 15, 12),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 15, 12, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 15, 12),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18210 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18210,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 15, 15),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 15, 15, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 15, 15),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18211 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18211,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 15, 18),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 15, 18, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 15, 18),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18212 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18212,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 15, 21),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 15, 21, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 15, 21),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18213 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18213,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 15, 24),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 15, 24, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 15, 24),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18214 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18214,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 15, 27),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 15, 27, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 15, 27),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18215 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18215,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 15, 30),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 15, 30, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 15, 30),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18216 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18216,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 15, 33),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 15, 33, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 15, 33),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18217 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18217,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 15, 36),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 15, 36, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 15, 36),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18218 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18218,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 15, 39),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 15, 39, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 15, 39),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18219 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18219,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 15, 42),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 15, 42, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 15, 42),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18220 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18220,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 15, 45),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 15, 45, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 15, 45),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18221 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18221,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 15, 48),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 15, 48, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 15, 48),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18222 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18222,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 15, 51),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 15, 51, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 15, 51),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18223 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18223,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 15, 54),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 15, 54, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 15, 54),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18224 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18224,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 15, 57),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
# ...
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18261,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 18, 12),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 18, 12, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 18, 12),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18262 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18262,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 18, 15),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 18, 15, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 18, 15),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18263 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18263,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 18, 18),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 18, 18, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 18, 18),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18264 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18264,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 18, 21),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 18, 21, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 18, 21),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18265 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18265,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 18, 24),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 18, 24, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 18, 24),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18266 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18266,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 18, 27),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 18, 27, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 18, 27),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18267 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18267,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 18, 30),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 18, 30, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 18, 30),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18268 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18268,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 18, 33),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 18, 33, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 18, 33),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18269 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18269,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 18, 36),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 18, 36, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 18, 36),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18270 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18270,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 18, 39),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 18, 39, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 18, 39),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18271 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18271,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 18, 42),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 18, 42, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 18, 42),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18272 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18272,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 18, 45),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 18, 45, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 18, 45),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18273 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18273,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 18, 48),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 18, 48, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 18, 48),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18274 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18274,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 18, 51),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 18, 51, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 18, 51),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18275 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18275,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 18, 54),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 18, 54, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 18, 54),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None
# Funding event #18276 deposit 71.875852 tokens for strategy reserves at block 0 from None
# {'asset': {'address': '0x2791bca1f2de4661ed88a30c99a7a9449aa84174',
#            'chain_id': 137,
#            'decimals': 6,
#            'info_url': None,
#            'internal_id': None,
#            'liquidation_threshold': None,
#            'token_symbol': 'USDC',
#            'type': None,
#            'underlying': None},
#  'balance_update_id': 18276,
#  'block_mined_at': datetime.datetime(2023, 12, 13, 18, 57),
#  'block_number': None,
#  'cause': <BalanceUpdateCause.deposit: 'deposit'>,
#  'chain_id': 137,
#  'created_at': datetime.datetime(2023, 12, 13, 18, 57, 1),
#  'log_index': None,
#  'notes': None,
#  'old_balance': Decimal('0'),
#  'owner_address': None,
#  'position_id': None,
#  'position_type': <BalanceUpdatePositionType.reserve: 'reserve'>,
#  'previous_update_at': None,
#  'quantity': Decimal('71.875852'),
#  'strategy_cycle_included_at': datetime.datetime(2023, 12, 13, 18, 57),
#  'tx_hash': None,
#  'usd_value': 71.875852}
# None

# %%
from tradeexecutor.analysis.position import display_reserve_position_events

df = display_reserve_position_events(position)
display(df)
# Out:
#          Cause                  At   Quantity  Dollar value Address Notes
# 6084   deposit 2023-11-07 13:53:49   61.19656     61.196560
# 6085   deposit 2023-11-07 13:54:00   61.19656     61.196560
# 6086   deposit 2023-11-07 13:57:00   61.19656     61.196560
# 6087   deposit 2023-11-07 14:20:32   61.19656     61.196560
# 6088   deposit 2023-11-07 14:21:00   61.19656     61.196560
# ...        ...                 ...        ...           ...     ...   ...
# 18272  deposit 2023-12-13 18:45:00  71.875852     71.875852
# 18273  deposit 2023-12-13 18:48:00  71.875852     71.875852
# 18274  deposit 2023-12-13 18:51:00  71.875852     71.875852
# 18275  deposit 2023-12-13 18:54:00  71.875852     71.875852
# 18276  deposit 2023-12-13 18:57:00  71.875852     71.875852
#
# [12193 rows x 6 columns]

# %% [markdown]
# ## Position profit history

# %%
from io import StringIO
from typing import Iterable, List
import pandas as pd

from tradeexecutor.state.position import TradingPosition

positions = state.portfolio.closed_positions.values()

data = [(p.closed_at, p.position_id, p.get_realised_profit_percent() * 100, p.is_repaired()) for p in positions]

df = pd.DataFrame(data, columns=("date", "position id", "position profit %", "failed trades"))
df = df.set_index("date")

df = df.sort_values("position profit %", ascending=True)

pd.set_option('display.max_rows', 100)

df
# Out:
#                      position id  position profit %  failed trades
# date
# 2023-10-24 22:56:40            3         -55.051863          False
# 2023-11-21 18:10:49           88          -9.023649          False
# 2023-12-10 15:08:10          105          -6.000636          False
# 2023-10-26 15:04:51           11          -5.522145          False
# 2023-11-17 12:03:59           81          -5.166125          False
# ...                          ...                ...            ...
# 2023-11-14 05:27:13           74           3.482485          False
# 2023-11-02 01:30:16           33           5.287333          False
# 2023-10-28 10:36:22           16           5.961395          False
# 2023-10-26 07:54:20            7          63.448862           True
# 2023-10-26 03:57:24            5         135.833485           True
#
# [106 rows x 3 columns]

# %% [markdown]
# ## Check prolematic position

# %%
p: TradingPosition
p = state.portfolio.closed_positions[22]
print("Position", p)
print("Realised profit", p.get_realised_profit_percent())
print("Avg buy", p.get_average_buy())
print("Avg sell", p.get_average_sell())
print("Buy value", p.get_buy_value())
print("Sell value", p.get_sell_value())
print("Balance updates")
for id, bu in p.balance_updates.items():
    print(bu)
# Out:
# Position <Closed position #22 <Pair SAND-WMATIC spot_market_hold at 0x369582d2010b6ed950b571f4101e3bb9b554876f (0.3000% fee) on exchange 0x5757371414417b8c6caad45baef941abc7d3ab32> $4.897948>
# Realised profit 0.010607911721398411
# Avg buy 0.35133529775086475
# Avg sell 0.3550622315740171
# Buy value 4.897948
# Sell value 4.949905
# Balance updates
