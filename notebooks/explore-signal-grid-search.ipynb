# %% [markdown]
# # Grid search signal/price movement relationship
#
# See [explore-signal.ipynb](./explore-signal.ipynb).

# %%
import datetime

import pandas as pd

from tradingstrategy.client import Client
from tradingstrategy.chain import ChainId
from tradingstrategy.timebucket import TimeBucket
from tradeexecutor.utils.default_strategies import get_default_strategies_path
from tradeexecutor.strategy.execution_context import notebook_execution_context
from tradeexecutor.utils.default_strategies import get_default_strategies_path
from tradeexecutor.strategy.strategy_module import read_strategy_module
from tradeexecutor.strategy.trading_strategy_universe import TradingStrategyUniverse, load_trading_and_lending_data
from tradeexecutor.strategy.universe_model import UniverseOptions


def create_trading_universe(
    ts: datetime.datetime,
    client: Client,
    execution_context,
    universe_options,
) -> TradingStrategyUniverse:
    
    dataset = load_trading_and_lending_data(
        client,
        execution_context=execution_context,
        universe_options=universe_options,
        # Ask for all Polygon data
        chain_id=ChainId.polygon,
        exchange_slugs={"uniswap-v3"},
        reserve_asset_symbols={"USDC"},
        asset_symbols={"LINK", "WMATIC", "WETH"},
        trading_fee=0.0005,  # Only use pairs at 0.05% fee tier
        time_bucket=TimeBucket.h4,
    )

    universe = TradingStrategyUniverse.create_from_dataset(dataset)

    return universe


client = Client.create_jupyter_client()

strategy_universe = create_trading_universe(
    datetime.datetime.utcnow(),
    client,
    notebook_execution_context,
    UniverseOptions(start_at=pd.Timestamp("2022-01-01"), end_at=pd.Timestamp("2023-11-01")),
)

data_universe = strategy_universe.data_universe
# Out:
# Started Trading Strategy in Jupyter notebook environment, configuration is stored in /Users/moo/.tradingstrategy
# Downloading interest rate data for 4 assets:   0%|          | 0/8 [00:00<?, ?it/s]

# %% [markdown]
# ## Explore signal vs price change
#
# Create a function `calculate_signal_vs_profit` which calculates
# - Signal (naive momentum)
# - Profit: the last and the best future price we can get
# - Allows us to play around with different time windows
# - Split between shorts and longs

# %%
import numpy as np
from pandas.tseries.frequencies import to_offset

from tradingstrategy.utils.forward_fill import forward_fill
from tradingstrategy.pair import DEXPair


def calculate_signal_vs_profit(
    df, 
    signal_window: pd.Timedelta, 
    profit_window: pd.Timedelta,
    data_time_bucket: pd.Timedelta,        
) -> pd.DataFrame:
    """Calculate signals and profits for all incoming candles."""
    
    # Create entries for past price to be used for signal
    # and future price (used for the price correlation)
    signal_offset = to_offset(signal_window)
    profit_offset = to_offset(profit_window)

    df["prev"] = df["close"].shift(freq=signal_offset)
    df["next"] = df["open"].shift(freq=-profit_offset)

    # Calculate signal from the past and price difference to the future
    df["signal"] = (df["prev"] - df["open"]) / df["open"]
    df["price_diff"] = (df["next"] - df["open"]) / df["open"]  # Get the profit on the final day of profit window

    # On negative signals, we go short.
    # On zero signal and lack of data set side to NA
    df["side"] = pd.NA
    df.loc[df["signal"] > 0, "side"] = "long"
    df.loc[df["signal"] < 0, "side"] = "short"

    number_of_candles = profit_window / data_time_bucket
    assert number_of_candles > 0 and number_of_candles.is_integer(), f"Could not calculate candle count that fits into profit window {profit_window} for data time frame {data_time_bucket}"
    number_of_candles = int(number_of_candles)

    # Max and min price wihtin the profit window will determine the profit for longs and shorts respective
    df["max_future_price"] = df["close"].rolling(number_of_candles).max().shift(-number_of_candles) # Get the max profit on the profit window, assuming take profit %
    df["min_future_price"] = df["close"].rolling(number_of_candles).min().shift(-number_of_candles) # Get the max profit on the profit window, assuming take profit %    
    
    # Calculate profit separately for longs and shorts
    # using Pandas Mask
    # https://stackoverflow.com/a/33770421/315168
    #
    # We calculate both profit after X time,
    # and also max take profit, assuming
    # we could do a perfect trailing stop loss
    #
    longs = (df["side"] == "long")
    shorts = (df["side"] == "short")
    df.loc[longs, "profit"] = df["price_diff"]
    df.loc[shorts, "profit"] = -df["price_diff"]
    df.loc[longs, "profit_max"] = (df["max_future_price"] - df["open"]) / df["open"]  # Get the profit based on max price
    df.loc[shorts, "profit_max"] = -(df["min_future_price"] - df["open"]) / df["open"]  # Get the profit based on max price

    df.loc[longs, "desc"] = df.agg('{0[pair]} long'.format, axis=1)
    df.loc[shorts, "desc"] = df.agg('{0[pair]} short'.format, axis=1)
    
    return df

# %% [markdown]
# Create a function `calculate_signal_vs_price_for_pair` which calculates
# - Calculates the signal vs. for certain trading pair
# - Bundle few different pairs to the same `DataFrame` so we can examine them together

# %%
def calculate_signal_vs_price_for_pair(
    df: pd.DataFrame, 
    signal_window=pd.Timedelta(days=7),
    profit_window=pd.Timedelta(days=7),
) -> pd.DataFrame:
    """Calculate signal vs. profit ratio for an individual pair."""

    df = calculate_signal_vs_profit(
        df,
        signal_window,
        profit_window,
        data_time_bucket=data_universe.time_bucket.to_pandas_timedelta(),
    )

    return df

# %%
# Pull out trading pair details for pairs we are examining
pairs = data_universe.pairs
examined_pairs = [
    pairs.get_pair_by_human_description([ChainId.polygon, "uniswap-v3", "WETH", "USDC"]),
    pairs.get_pair_by_human_description([ChainId.polygon, "uniswap-v3", "LINK", "USDC"]),
    pairs.get_pair_by_human_description([ChainId.polygon, "uniswap-v3", "WMATIC", "USDC"]),
]

# %% [markdown]
# # Prepare trading pair data

# %%
pair_dfs = []
for pair in examined_pairs:
    df = data_universe.candles.get_candles_by_pair(pair)
    assert df is not None
    df = df.copy()      
    df = forward_fill(
        df, 
        freq=data_universe.time_bucket.to_frequency(), 
        columns=("open", "high", "low", "close")
    )
    df["pair"] = pair.get_ticker()
    pair_dfs.append(df)

print(f"Prepared trading pair data for {len(pair_dfs)} pairs")
# Out:
# Prepared trading pair data for 3 pairs

# %% [markdown]
# ## Grid search correlative parameters
#
# Grid search for the best lookback and look foward parametrs.
#
# - Go from 4 hours to 14 days for both parameters
# - We use a background worker pool to speed up the computation, by allocating background threads/workers for each task

# %%
import futureproof
import statsmodels.api as sm

from tqdm.auto import tqdm

look_backs = [pd.Timedelta(hours=hours) for hours in range(4, 30*24, 16)]
look_forwards = [pd.Timedelta(hours=hours) for hours in range(4, 30*24, 16)]

# look_backs = [pd.Timedelta(hours=hours) for hours in range(4, 12, 4)]
# look_forwards = [pd.Timedelta(hours=hours) for hours in range(4, 12, 4)]


def process_background_job(look_back: pd.Timedelta, look_forward: pd.Timedelta) -> tuple:
    # Create signal vs. price analysis for examined pairs and calculate correlation
    # Make a copy of DataFrame as it is mutated in-place
    signal_vs_profit = [calculate_signal_vs_price_for_pair(df.copy(), look_back, look_forward) for df in pair_dfs]
    
    # Calculate linear regression for signal vs. profit 
    df = pd.concat(signal_vs_profit)
    df = df.dropna()
    longs = df.loc[df["side"] == "long"]
    shorts = df.loc[df["side"] == "short"]

    # https://stackoverflow.com/a/54685349/315168
    #regression = sm.OLS(df["profit_max"], df["signal"]).fit()
    long_regression = sm.OLS(longs["profit_max"], longs["signal"]).fit()
    short_regression = sm.OLS(shorts["profit_max"], shorts["signal"]).fit()
    return look_back, look_forward, long_regression, short_regression

# %% [markdown]
# Run the grid search using a thread worker.

# %%
results = []

executor = futureproof.executors.ThreadPoolExecutor(max_workers=8)
with futureproof.TaskManager(executor, error_policy="log") as task_manager:
    
    # Send individual jobs to the multiprocess worker pool
    total_tasks = 0
    for look_back in look_backs:
        for look_forward in look_forwards:
            task_manager.submit(process_background_job, look_back, look_forward)
            total_tasks += 1

    print(f"Processing grid search {total_tasks} background jobs")

    # Run the background jobs and read back the results from the background worker
    # with a progress bar
    with tqdm(total=total_tasks) as progress_bar:
        for task in task_manager.as_completed():
            if isinstance(task.result, Exception):
                executor.join()
                raise RuntimeError(f"Could not complete task for args {task.args}") from task.result
            
            look_back, look_forward, long_regression, short_regression = task.result
            results.append([
                look_back,
                look_forward,
                long_regression.rsquared,
                short_regression.rsquared
            ])
            progress_bar.update()


# Display grid search results and give a background gradient colour based on 
# the performance of a grid combination
df = pd.DataFrame(results, columns=["Look back", "Look forward", "Regression long", "Regression short"])

value_cols = ["Regression long", "Regression short"]

formatted = df.style.background_gradient(
    axis = 0,
    subset = value_cols,
).highlight_min(
    color = 'pink',
    axis = 0,
    subset = value_cols,
).highlight_max(
    color = 'darkgreen',
    axis = 0,
    subset = value_cols,
)

pd.set_option('display.min_rows', 5000)

print("Max long correlation")
display(df[df["Regression long"] == df["Regression long"].max()])

print("Max short correlation")
display(df[df["Regression short"] == df["Regression short"].max()])

display(formatted)
# Out:
# Processing grid search 2025 background jobs
#   0%|          | 0/2025 [00:00<?, ?it/s]
# Max long correlation             Look back     Look forward  Regression long  Regression short
# 1349 19 days 12:00:00 29 days 12:00:00         0.468239          0.483737
# Max short correlation             Look back     Look forward  Regression long  Regression short
# 2023 29 days 12:00:00 29 days 12:00:00         0.423188          0.540895
# <style type="text/css">
# #T_c4e9a_row0_col2 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_c4e9a_row0_col3 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_c4e9a_row1_col2, #T_c4e9a_row11_col2, #T_c4e9a_row14_col2, #T_c4e9a_row20_col2 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_c4e9a_row1_col3, #T_c4e9a_row37_col2, #T_c4e9a_row41_col2 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_c4e9a_row2_col2, #T_c4e9a_row3_col2, #T_c4e9a_row10_col2, #T_c4e9a_row12_col2, #T_c4e9a_row13_col2, #T_c4e9a_row15_col2 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_c4e9a_row2_col3, #T_c4e9a_row3_col3, #T_c4e9a_row6_col3 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_c4e9a_row4_col2, #T_c4e9a_row4_col3, #T_c4e9a_row223_col2, #T_c4e9a_row223_col3, #T_c4e9a_row269_col2, #T_c4e9a_row315_col2, #T_c4e9a_row1080_col2, #T_c4e9a_row1125_col2, #T_c4e9a_row1170_col2, #T_c4e9a_row1261_col2, #T_c4e9a_row1350_col2, #T_c4e9a_row1393_col2, #T_c4e9a_row1440_col2, #T_c4e9a_row1662_col2, #T_c4e9a_row1711_col2, #T_c4e9a_row1756_col2, #T_c4e9a_row1801_col2, #T_c4e9a_row1847_col2, #T_c4e9a_row1978_col2 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_c4e9a_row5_col2, #T_c4e9a_row6_col2, #T_c4e9a_row8_col2, #T_c4e9a_row16_col2, #T_c4e9a_row17_col2 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_c4e9a_row5_col3 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_c4e9a_row7_col2, #T_c4e9a_row9_col2, #T_c4e9a_row18_col2, #T_c4e9a_row19_col2, #T_c4e9a_row21_col2, #T_c4e9a_row23_col2, #T_c4e9a_row25_col2 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_c4e9a_row7_col3 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_c4e9a_row8_col3 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_c4e9a_row9_col3 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_c4e9a_row10_col3, #T_c4e9a_row11_col3, #T_c4e9a_row12_col3, #T_c4e9a_row13_col3, #T_c4e9a_row14_col3, #T_c4e9a_row15_col3, #T_c4e9a_row16_col3, #T_c4e9a_row17_col3, #T_c4e9a_row18_col3, #T_c4e9a_row19_col3, #T_c4e9a_row20_col3, #T_c4e9a_row21_col3, #T_c4e9a_row22_col3, #T_c4e9a_row23_col3, #T_c4e9a_row24_col3, #T_c4e9a_row25_col3, #T_c4e9a_row26_col3, #T_c4e9a_row27_col3, #T_c4e9a_row28_col3 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_c4e9a_row22_col2, #T_c4e9a_row24_col2, #T_c4e9a_row26_col2, #T_c4e9a_row27_col2 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_c4e9a_row28_col2, #T_c4e9a_row29_col2, #T_c4e9a_row30_col2, #T_c4e9a_row31_col2, #T_c4e9a_row32_col2, #T_c4e9a_row33_col2, #T_c4e9a_row34_col2, #T_c4e9a_row35_col2, #T_c4e9a_row36_col2, #T_c4e9a_row38_col2, #T_c4e9a_row39_col2, #T_c4e9a_row40_col2, #T_c4e9a_row42_col2, #T_c4e9a_row43_col2, #T_c4e9a_row44_col2 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_c4e9a_row29_col3, #T_c4e9a_row32_col3, #T_c4e9a_row34_col3 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_c4e9a_row30_col3, #T_c4e9a_row31_col3, #T_c4e9a_row33_col3 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_c4e9a_row35_col3, #T_c4e9a_row36_col3, #T_c4e9a_row38_col3, #T_c4e9a_row39_col3 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_c4e9a_row37_col3, #T_c4e9a_row41_col3, #T_c4e9a_row42_col3 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_c4e9a_row40_col3 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_c4e9a_row43_col3 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_c4e9a_row44_col3 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_c4e9a_row45_col2, #T_c4e9a_row93_col3, #T_c4e9a_row362_col3, #T_c4e9a_row407_col3, #T_c4e9a_row541_col3, #T_c4e9a_row586_col3, #T_c4e9a_row1038_col3, #T_c4e9a_row1217_col3, #T_c4e9a_row1531_col3 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_c4e9a_row45_col3 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_c4e9a_row46_col2, #T_c4e9a_row59_col2, #T_c4e9a_row61_col2, #T_c4e9a_row149_col2, #T_c4e9a_row227_col2, #T_c4e9a_row285_col2, #T_c4e9a_row320_col2, #T_c4e9a_row332_col2, #T_c4e9a_row386_col2, #T_c4e9a_row429_col2, #T_c4e9a_row479_col2, #T_c4e9a_row525_col2, #T_c4e9a_row568_col2, #T_c4e9a_row570_col2, #T_c4e9a_row607_col2, #T_c4e9a_row650_col2, #T_c4e9a_row692_col2, #T_c4e9a_row735_col2, #T_c4e9a_row864_col2 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_c4e9a_row46_col3, #T_c4e9a_row1578_col3, #T_c4e9a_row1622_col3 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_c4e9a_row47_col2, #T_c4e9a_row47_col3, #T_c4e9a_row90_col2, #T_c4e9a_row90_col3, #T_c4e9a_row135_col3, #T_c4e9a_row180_col3, #T_c4e9a_row269_col3, #T_c4e9a_row315_col3, #T_c4e9a_row358_col2, #T_c4e9a_row358_col3, #T_c4e9a_row403_col2, #T_c4e9a_row403_col3, #T_c4e9a_row450_col2, #T_c4e9a_row450_col3, #T_c4e9a_row494_col2, #T_c4e9a_row494_col3, #T_c4e9a_row540_col2, #T_c4e9a_row540_col3, #T_c4e9a_row585_col2, #T_c4e9a_row585_col3, #T_c4e9a_row631_col2, #T_c4e9a_row631_col3, #T_c4e9a_row676_col2, #T_c4e9a_row676_col3, #T_c4e9a_row720_col2, #T_c4e9a_row765_col2, #T_c4e9a_row765_col3, #T_c4e9a_row812_col2, #T_c4e9a_row812_col3, #T_c4e9a_row855_col3, #T_c4e9a_row900_col2, #T_c4e9a_row900_col3, #T_c4e9a_row944_col2, #T_c4e9a_row944_col3, #T_c4e9a_row990_col2, #T_c4e9a_row990_col3, #T_c4e9a_row1035_col2, #T_c4e9a_row1035_col3, #T_c4e9a_row1080_col3, #T_c4e9a_row1125_col3, #T_c4e9a_row1170_col3, #T_c4e9a_row1216_col3, #T_c4e9a_row1261_col3, #T_c4e9a_row1305_col2, #T_c4e9a_row1305_col3, #T_c4e9a_row1350_col3, #T_c4e9a_row1393_col3, #T_c4e9a_row1440_col3, #T_c4e9a_row1485_col3, #T_c4e9a_row1529_col3, #T_c4e9a_row1576_col3, #T_c4e9a_row1620_col3, #T_c4e9a_row1662_col3, #T_c4e9a_row1711_col3, #T_c4e9a_row1756_col3, #T_c4e9a_row1801_col3, #T_c4e9a_row1847_col3, #T_c4e9a_row1890_col2, #T_c4e9a_row1890_col3, #T_c4e9a_row1934_col2, #T_c4e9a_row1934_col3, #T_c4e9a_row1978_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_c4e9a_row48_col2, #T_c4e9a_row60_col3, #T_c4e9a_row68_col2, #T_c4e9a_row98_col3, #T_c4e9a_row99_col3, #T_c4e9a_row155_col2, #T_c4e9a_row178_col2, #T_c4e9a_row184_col2, #T_c4e9a_row251_col2, #T_c4e9a_row296_col2, #T_c4e9a_row318_col3, #T_c4e9a_row349_col2, #T_c4e9a_row350_col2, #T_c4e9a_row356_col2, #T_c4e9a_row357_col2, #T_c4e9a_row409_col3, #T_c4e9a_row448_col2, #T_c4e9a_row492_col2, #T_c4e9a_row539_col2, #T_c4e9a_row582_col2, #T_c4e9a_row655_col2, #T_c4e9a_row810_col3, #T_c4e9a_row911_col2, #T_c4e9a_row957_col2, #T_c4e9a_row994_col2, #T_c4e9a_row1442_col3, #T_c4e9a_row1757_col2 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
# }
# #T_c4e9a_row48_col3, #T_c4e9a_row92_col3, #T_c4e9a_row542_col2, #T_c4e9a_row589_col2, #T_c4e9a_row1351_col2 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_c4e9a_row49_col2, #T_c4e9a_row74_col2, #T_c4e9a_row86_col2, #T_c4e9a_row102_col3, #T_c4e9a_row111_col2, #T_c4e9a_row118_col2, #T_c4e9a_row129_col2, #T_c4e9a_row130_col2, #T_c4e9a_row131_col2, #T_c4e9a_row133_col2, #T_c4e9a_row156_col2, #T_c4e9a_row157_col2, #T_c4e9a_row210_col2, #T_c4e9a_row254_col2, #T_c4e9a_row255_col2, #T_c4e9a_row256_col2, #T_c4e9a_row311_col2, #T_c4e9a_row312_col2, #T_c4e9a_row313_col2, #T_c4e9a_row314_col2, #T_c4e9a_row659_col2, #T_c4e9a_row664_col2, #T_c4e9a_row665_col2, #T_c4e9a_row699_col2, #T_c4e9a_row740_col2, #T_c4e9a_row784_col2, #T_c4e9a_row902_col3, #T_c4e9a_row1041_col2, #T_c4e9a_row1307_col2, #T_c4e9a_row1533_col3, #T_c4e9a_row1716_col3, #T_c4e9a_row1762_col3, #T_c4e9a_row1849_col2 {
#   background-color: #549cc7;
#   color: #f1f1f1;
# }
# #T_c4e9a_row49_col3, #T_c4e9a_row1578_col2, #T_c4e9a_row1846_col3 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_c4e9a_row50_col2, #T_c4e9a_row70_col2, #T_c4e9a_row72_col2, #T_c4e9a_row73_col2, #T_c4e9a_row89_col2, #T_c4e9a_row97_col2, #T_c4e9a_row112_col2, #T_c4e9a_row119_col2, #T_c4e9a_row134_col2, #T_c4e9a_row140_col3, #T_c4e9a_row161_col2, #T_c4e9a_row162_col2, #T_c4e9a_row208_col2, #T_c4e9a_row253_col2, #T_c4e9a_row303_col2, #T_c4e9a_row588_col3, #T_c4e9a_row626_col2, #T_c4e9a_row679_col3, #T_c4e9a_row721_col3, #T_c4e9a_row827_col2, #T_c4e9a_row870_col2, #T_c4e9a_row912_col2, #T_c4e9a_row958_col2, #T_c4e9a_row995_col2, #T_c4e9a_row1
