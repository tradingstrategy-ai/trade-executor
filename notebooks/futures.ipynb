# %%
# https://api.binance.com/api/v3/exchangeInfo

from tradingstrategy.binance.downloader import BinanceDownloader


# downloader = BinanceDownloader()
# _margin_assets = downloader.fetch_assets('MARGIN')
margin_assets = list(_margin_assets)
print(len(margin_assets))
# Out:
# 0

# %%
start =289
print(margin_assets[start:start+11])

# %%
from tradingstrategy.chain import ChainId

# chain_id, address, tvl, has_lending

futures_mappings = {
    "ETHBTC": (ChainId.ethereum, '0xceff51756c56ceffca006cd410b03ffc46dd3a58'),
    "BNBBTC": (ChainId.binance, '0x61eb789d75a95caa3ff50ed7e47b96c132fec082'),
    "BNBETH": (ChainId.binance, '0x74e4716e431f45807dcf19f284c7aa99f18a4fbc'),
    "BTCUSDT": [
        (ChainId.ethereum, "uniswap-v3", '0x9db9e0e53058c89e5b94e29621a205198648425b', "9.71M", "0.3%"), # USDT
        (ChainId.ethereum, "uniswap-v3", '0x99ac8ca7087fa4a2a1fb6357269965a2014abc35', "20.00M", "0.3%"), # USDC
        (ChainId.ethereum, "uniswap-v3", '0x9a772018fbd77fcd2d25657e5c547baff3fd7d16', "5.85M", "0.05%"), # USDC
        (ChainId.arbitrum, "uniswap-v3", '0x5969efdde3cf5c0d9a88ae51e47d721096a97203', "2.2M", "0.05%"), # USDT
        (ChainId.binance, "pancakeswap-v2", '0x5840b79d19c053a79923df738a251426d8879308', "1.36M", "0.25%"), # USDT
        (ChainId.arbitrum, "uniswap-v3", '0xac70bd92f89e6739b3a08db9b6081a923912f73d', "262.26K", "0.05%"), # USDC
    ],
    "ETHUSDT": [
        (ChainId.ethereum, "uniswap-v3", '0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640', '151.99M', "0.05%"), # USDC
        (ChainId.arbitrum, "uniswap-v3", '0x641c00a822e8b671738d32a431a4fb6074e5c79d', '12.38M', "0.05%"), # USDT 
        (ChainId.arbitrum, "uniswap-v3", '0xc31e54c7a869b9fcbecc14363cf510d1c41fa443', '9.26M', "0.05%"), # USDC
        (ChainId.binance, "biswap", '0x63b30de1a998e9e64fd58a21f68d323b9bcd8f85', '3.18M', "0.3%"), # USDT
    ],
    "ETHBNB": (ChainId.binance, '0x74e4716e431f45807dcf19f284c7aa99f18a4fbc', '4.12M'),
    "LINKETH": (ChainId.ethereum, "0xa2107fa5b38d9bbd2c461d6edf11b11a50f6b974", '2.63M'),
    "XRTETH": (ChainId.ethereum, "0xb49159afeb54f8922b0a82a5d58bd4728b8c20bb", '113.92K'),
    "BNBUSDT": [
        (ChainId.binance, "pancakeswap-v2", "0x16b9a82891338f9ba80e2d6970fdda79d1eb0dae", "14.00M", "0.25%"), # USDT
        (ChainId.binance, "pancakeswap-v2", "0xd99c7f6c65857ac913a8f880a4cb84032ab2fc5b", "727.80K", "0.25%"), # USDC
    ],
    "LTCUSDT": (ChainId.binance, "biswap", "0x412b607f4cbe9cae77c6f720a701cd60fa0ebd3f", "396.92K", "0.3%"),
    "TUSDUSDT": (ChainId.arbitrum, "uniswap-v3", "0xad397a0472503b066ab4b311d66fa1f659f4cb61", "192.42K", "0.05%"),
    "TUSDUSDT": (ChainId.ethereum, "uniswap-v3", "0x69ef438a28e6d123f809c9be785c79745ab5a0b8", "144K", "1%"),
    "CAKEUSDT": (ChainId.binance, "pancakeswap-v2", "0xa39af17ce4a8eb807e076805da1e2b8ea7d0755b", "1.53M", "0.25%"),
    "BADGERBTC": (ChainId.ethereum, "uniswap-v2", "0xcd7989894bc033581532d2cd88da5db0a4b12859", "1.08M", "0.3%"),
    "PONDUSDT": (ChainId.ethereum, "uniswap-v2", "0xd18748b9839b0081a867a1a871d5b562b2ec9884", "472K", "0.3%"), # USDC
    "PONDUSDT": (ChainId.ethereum, "uniswap-v2", "0xd18748b9839b0081a867a1a871d5b562b2ec9884", "472K", "0.3%"), # USDC
    "ALICEUSDT": (ChainId.ethereum, "uniswap-v3", "0xde93684627d4e34d6ef96adf5bcabf10bbd8dd81", "141K", "0.3%"),
    "BAKEUSDT": (ChainId.binance, "bakeryswap", "0x6e218ea042bef40a8baf706b00d0f0a7b4fce50a", "187K", "0.3%"), # BUSD
    "MDXUSDT": (ChainId.binance, "erosswap", "0x223740a259e461abee12d84a9fff5da69ff071dd", "249K", "0.3%"), # BUSD
    "MASKUSDT": (ChainId.ethereum, "uniswap-v2", "0xa40bb1c47f6dd27142a2bd7c93bfa98db9d1f5c5", "1,27M", "0.3%"), # USDC
    "BONDUSDT": (ChainId.ethereum, "uniswap-v2", "0x6591c4bcd6d7a1eb4e537da8b78676c1576ba244", "234K", "0.3%"), # USDC
    "MLNUSDT": (ChainId.ethereum, "uniswap-v3", "0x79599e9097866e3b274c00175fd92760af5e65fa", "310K", "1%"), #USDC
    "FLOWUSDT": (ChainId.ethereum, "uniswap-v3", "0xd4292615a8e9edc07cba49c1a9cbb93b873a181e", "591.52K", "0.3%"), # USDC
    "QUICKUSDT": (ChainId.polygon, "quickswap", "0x1f1e4c845183ef6d50e9609f16f6f9cae43bc9cb", "177K", "0.3%"), # USDC
    "REQUSDC": [
        (ChainId.ethereum, "uniswap-v2", "0xeb4b2b5e0eae7a0eadd0673ef8c3c830f8762f28", "196K", "0.3%"), # USDC
        (ChainId.ethereum, "uniswap-v2", "0x2b9f8fe8ffc437a9008bb3097066f02b0a1c52ec", "185K", "0.3%"), # USDT
    ],
    "GHSTUSDT": (ChainId.polygon, "quickswap", "0x096c5ccb33cfc5732bcd1f3195c13dbefc4c82f4", "1.05M", "0.3%"), # USDC
    "WAXPUSDT": (ChainId.ethereum, "uniswap-v3", "0xe61cedeb1593e2d9f06af1e212842c8b5e289863", "1.04M", "0.3%"), # USDT
    "SOLUSDC": (ChainId.binance, "babyswap", "0xae08c9d357731fd8d25681de753551be14c00405", "168K", "0.3%"), # USDC
    "RADUSDT": (ChainId.ethereum, "uniswap-v2", "0x8c1c499b1796d7f3c2521ac37186b52de024e58c", "4.29M", "0.3%"), # USDC
    "CHESSUSDT": (ChainId.binance, "pancakeswap-v2", "0x1472976e0b97f5b2fc93f1fff14e2b5c4447b64f", "363K", "0.25%"), # USDC
    "ADXUSDT": (ChainId.ethereum, "uniswap-v3", "0x8de5977111c68c3fe95e63e7f7319dd5a01f77a0", "294K", "0.3%"), #USDT
    "BNXUSDT": (ChainId.binance, "pancakswap-v2", "0xb72723e36a83fb5fe1793f06b436f4720f5de4f9", "3.33M", "0.25%"), # BUSD
    "ENSUSDT": (ChainId.ethereum, "uniswap-v3", "0x09aa63b7a22eefc372196aacd5b53441ed390bfb", "148K", "0.3%"), # USDT
    "HIGHUSDT": [
        (ChainId.binance, "unknown", "0xcd254486fb8f5a776d8780504b87a55b80c669dc", "158K", "0.3%"), # BUSD
        (ChainId.binance, "pancakeswap-v2", "0xe98ac95a1db2fcaaa9c7d4ba7ecfce4877ca2bea", "144K", "0.25%") # BUSD
    ],
    "GMTUSDT": [
        (ChainId.polygon, "mooar", "0xb064e9b00d713496d54617c3ef6e659072b8339f", "5.57M", "0.3%"), # USDT
        (ChainId.ethereum, "notdao", "0xaeaca8c32039a466fb32bde6f566130a1f49d21e", "2.03M", "0.3%"), # USDC
        (ChainId.binance, "pancakeswap-v2", "0x007ec643c7cc33a70c083fc305c283dd009c8b94", "154K", "0.25%"), # USDC
    ],
    "BSWUSDT": (ChainId.binance, "biswap", "0x2b30c317cedfb554ec525f85e79538d59970beb0", "757K", "0.3%"), # USDT
    "GALUSDT": (ChainId.ethereum, "uniswap-v3", "0xf92f2e3fca01491baba0975264362cc38b1cab7b", "7.41M", "1%"), # USDC
    "STGUSDT": [
        (ChainId.ethereum, "uniswap-v3", "0x8592064903ef23d34e4d5aaaed40abf6d96af186", "3.13M", "1%") # USDC
        (ChainId.avalanche, "trader-joe", "0x330f77bda60d8dab14d2bb4f6248251443722009", "1.63M", "0.3%") # USDC
        (ChainId.polygon, "susi", "0xa34ec05da1e4287fa351c74469189345990a3f0c", "1.43M", "0.3%") # USDC
    ],
    "HIFIUSDT": (ChainId.ethereum, "uniswap-v3", "0xc4480526e3d64f7ec7d7a6694c52d23aab658ed5", "303K", "1%") # USDC
    "PROSUSDT": (ChainId.ethereum, "uniswap-v2", "0x3155acd9f75915fcc21d34035f440da7040bd3ba", "279K", "0.3%"), # USDC
    "AGIXUSDT": (ChainId.ethreum, "uniswap-v2", "0x4bb0925fa50da9b4c8936869433b48e78ccc5c13", "299K", "0.3%") # USDT
    "GNSUSDT": [
        (ChainId.arbitrum, "uniswap-v3", "0x4d2fe06fd1c4368042b926d082484d2e3cc8f3f5", "177.64K", "1%"), # DAI
        (ChainId.polygon, "quickswap", "0x6e53cb6942e518376e9e763554db1a45ddcd25c4", "110.57K", "0.3%"), # DAI
    ],
    

}

# %%
start =449
print(margin_assets[start:start+11])
print(margin_assets[start+11:start+21])
print(margin_assets[start+21:start+31])
# Out:
# ['HIFIUSDT', 'RPLUSDT', 'PROSUSDT', 'AGIXUSDT', 'GNSUSDT', 'SYNUSDT', 'VIBUSDT', 'SSVUSDT', 'LQTYUSDT', 'AMBUSDT', 'USTCUSDT']
# ['GASUSDT', 'GLMUSDT', 'PROMUSDT', 'QKCUSDT', 'UFTUSDT', 'IDBTC', 'IDUSDT', 'ARBBTC', 'ARBUSDT', 'LOOMUSDT']
# ['OAXUSDT', 'ARBTUSD', 'RDNTUSDT', 'WBTCUSDT', 'EDUUSDT', 'SUIUSDT', 'SUITUSD', 'AERGOUSDT', 'PEPEUSDT', 'FLOKIUSDT']
