# %% [markdown]
# # RSI momentum trading strategy example
#
# - This is a backtest example notebook
#     - Check the result of ETH-BTC-USDC strategy module using Polygon data proper
#
# # Set up
#
# Set up Trading Strategy data client.

# %%
from tradeexecutor.utils.notebook import setup_charting_and_output
from tradingstrategy.client import Client

client = Client.create_jupyter_client()


# Render for Github web viewer
from tradeexecutor.utils.notebook import setup_charting_and_output, OutputMode

#setup_charting_and_output(OutputMode.static, image_format="png", width=1500, height=1000)
setup_charting_and_output(width=1500, height=1000)
# Out:
# Started Trading Strategy in Jupyter notebook environment, configuration is stored in /Users/moo/.tradingstrategy

# %% [markdown]
# # Backtest

# %%
from tradeexecutor.utils.jupyter_notebook_folder import get_strategies_folder
from tradeexecutor.cli.log import setup_notebook_logging
from tradeexecutor.strategy.execution_context import notebook_execution_context
from tradeexecutor.backtest.backtest_module import run_backtest_for_module

setup_notebook_logging()

state, strategy_universe, _ = run_backtest_for_module(
    get_strategies_folder() / "eth-btc-usdc.py",
    execution_context=notebook_execution_context,
)
# Out:
# Started Trading Strategy in Jupyter notebook environment, configuration is stored in /Users/moo/.tradingstrategy
#   0%|          | 0/2 [00:00<?, ?it/s]
# Reading cached indicators rsi, eth_btc, eth_btc_rsi for 2 pairs, using 8 threads:   0%|          | 0/4 [00:00<…
# Using indicator cache /Users/moo/.cache/tradingstrategy/indicators/centralised-exchange_1h_BTC-USDT-ETH-USDT_2019-01-01-2024-03-15
#   0%|          | 0/164131200 [00:00<?, ?it/s]

# %% [markdown]
# # Equity curve

# %%
from tradeexecutor.analysis.multi_asset_benchmark import get_benchmark_data
from tradeexecutor.visual.benchmark import visualise_equity_curve_benchmark

benchmark_indexes = get_benchmark_data(
    strategy_universe,
    cumulative_with_initial_cash=state.portfolio.get_initial_cash()
)

fig = visualise_equity_curve_benchmark(
    name=state.name,
    portfolio_statistics=state.stats.portfolio,
    all_cash=state.portfolio.get_initial_cash(),
    benchmark_indexes=benchmark_indexes,
    height=800,
    log_y=False,
)

fig.show()

# %% [markdown]
# # Portfolio benchmark

# %%
from tradeexecutor.analysis.multi_asset_benchmark import compare_strategy_backtest_to_multiple_assets

compare_strategy_backtest_to_multiple_assets(
    state,
    strategy_universe
)
# Out:
#                            Strategy         BTC         ETH
# Start Period             2019-01-01  2019-01-01  2019-01-01
# End Period               2024-03-14  2024-03-14  2024-03-14
# Risk-Free Rate                    0           0           0
# Time in Market                 0.36         1.0         1.0
# Cumulative Return             24.39        17.8       26.91
# CAGR﹪                          0.86        0.76         0.9
# Sharpe                         1.82        1.18        1.18
# Prob. Sharpe Ratio              1.0         1.0         1.0
# Sortino                        3.39        1.74        1.74
# Sortino/√2                      2.4        1.23        1.23
# Omega                           1.6         1.6         1.6
# Max Drawdown                  -0.22       -0.77       -0.79
# Longest DD Days                 270         846         856
# Gain/Pain Ratio                 0.6        0.21         0.2
# Gain/Pain (1M)                 3.03        1.39        1.43
# Payoff Ratio                   1.58        1.41        1.35
# Profit Factor                   1.6        1.21         1.2
# Common Sense Ratio             2.26        1.31        1.34
# CPC Index                      1.28        0.88        0.84
# Tail Ratio                     1.41        1.09        1.12
# Outlier Win Ratio             13.85        3.78        3.25
# Outlier Loss Ratio             2.72        3.31         3.0
# MTD                            0.07        0.17        0.16
# 3M                             0.45        0.67        0.72
# 6M                             0.72        1.72        1.41
# YTD                            0.48        0.69         0.7
# 1Y                              0.6        1.96        1.32
# 3Y (ann.)                       0.4        0.04         0.2
# 5Y (ann.)                      0.84        0.71         0.9
# 10Y (ann.)                     0.86        0.76         0.9
# All-time (ann.)                0.86        0.76         0.9
# Avg. Drawdown                 -0.06        -0.1       -0.14
# Avg. Drawdown Days               34          46          45
# Recovery Factor              112.17       23.23       33.93
# Ulcer Index                     0.1        0.42        0.46
# Serenity Index                 30.3        2.06        3.36
# Annualised return (raw)    0.862001         NaN         NaN

# %% [markdown]
# # Trading statistics

# %%
from tradeexecutor.analysis.trade_analyser import build_trade_analysis

analysis = build_trade_analysis(state.portfolio)
summary = analysis.calculate_summary_statistics()
display(summary.to_dataframe())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Trading period length</th>
#       <td>1893 days 16 hours</td>
#     </tr>
#     <tr>
#       <th><a href="https://tradingstrategy.ai/glossary/aggregate-return">Return %</a></th>
#       <td>2438.84%</td>
#     </tr>
#     <tr>
#       <th>Annualised return %</th>
#       <td>470.08%</td>
#     </tr>
#     <tr>
#       <th>Cash at start</th>
#       <td>$10,000.00</td>
#     </tr>
#     <tr>
#       <th>Value at end</th>
#       <td>$253,883.84</td>
#     </tr>
#     <tr>
#       <th>Time in market</th>
#       <td>25.51%</td>
#     </tr>
#     <tr>
#       <th><a href="https://tradingstrategy.ai/glossary/volume">Trade volume</a></th>
#       <td>$39,180,237.34</td>
#     </tr>
#     <tr>
#       <th><a href="https://tradingstrategy.ai/glossary/position">Position win percent</a></th>
#       <td>43.90%</td>
#     </tr>
#     <tr>
#       <th><a href="https://tradingstrategy.ai/glossary/position">Total positions</a></th>
#       <td>205</td>
#     </tr>
#     <tr>
#       <th><a href="https://tradingstrategy.ai/glossary/position">Won positions</a></th>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th><a href="https://tradingstrategy.ai/glossary/position">Lost positions</a></th>
#       <td>115</td>
#     </tr>
#     <tr>
#       <th><a href="https://tradingstrategy.ai/glossary/stop-loss">Stop losses triggered</a></th>
#       <td>71</td>
#     </tr>
#     <tr>
#       <th><a href="https://tradingstrategy.ai/glossary/stop-loss">Stop loss % of all</a></th>
#       <td>34.63%</td>
#     </tr>
#     <tr>
#       <th><a href="https://tradingstrategy.ai/glossary/stop-loss">Stop loss % of lost</a></th>
#       <td>61.74%</td>
#     </tr>
#     <tr>
#       <th><a href="https://tradingstrategy.ai/glossary/stop-loss">Winning stop losses</a></th>
#       <td>62</td>
#     </tr>
#     <tr>
#       <th><a href="https://tradingstrategy.ai/glossary/stop-loss">Winning stop losses percent</a></th>
#       <td>87.32%</td>
#     </tr>
#     <tr>
#       <th><a href="https://tradingstrategy.ai/glossary/stop-loss">Losing stop losses</a></th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th><a href="https://tradingstrategy.ai/glossary/stop-loss">Losing stop losses percent</a></th>
#       <td>12.68%</td>
#     </tr>
#     <tr>
#       <th><a href="https://tradingstrategy.ai/glossary/take-profit">Take profits triggered</a></th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th><a href="https://tradingstrategy.ai/glossary/take-profit">Take profit % of all</a></th>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <th><a href="https://tradingstrategy.ai/glossary/take-profit">Take profit % of won</a></th>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <th><a href="https://tradingstrategy.ai/glossary/position">Zero profit positions</a></th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th><a href="https://tradingstrategy.ai/glossary/open-position">Positions open at the end</a></th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th><a href="https://tradingstrategy.ai/glossary/realised-profit-and-loss">Realised profit and loss</a></th>
#       <td>$243,883.84</td>
#     </tr>
#     <tr>
#       <th><a href="https://tradingstrategy.ai/glossary/unrealised-profit-and-loss">Unrealised profit and loss</a></th>
#       <td>$0.00</td>
#     </tr>
#     <tr>
#       <th><a href="https://tradingstrategy.ai/glossary/unrealised-profit-and-loss">Portfolio unrealised value</a></th>
#       <td>$0.00</td>
#     </tr>
#     <tr>
#       <th><a href="https://tradingstrategy.ai/glossary/lending-pool">Extra returns on lending pool interest</a></th>
#       <td>$0.00</td>
#     </tr>
#     <tr>
#       <th>Cash left at the end</th>
#       <td>$253,883.84</td>
#     </tr>
#     <tr>
#       <th>Average winning position profit %</th>
#       <td>6.21%</td>
#     </tr>
#     <tr>
#       <th>Average losing position loss %</th>
#       <td>-2.67%</td>
#     </tr>
#     <tr>
#       <th>Biggest winning position %</th>
#       <td>25.70%</td>
#     </tr>
#     <tr>
#       <th>Biggest losing position %</th>
#       <td>-12.17%</td>
#     </tr>
#     <tr>
#       <th>Average duration of winning positions</th>
#       <td>5 days 15 hours</td>
#     </tr>
#     <tr>
#       <th>Average duration of losing positions</th>
#       <td>1 days 21 hours</td>
#     </tr>
#     <tr>
#       <th>Average duration between position openings</th>
#       <td>9 days 6 hours</td>
#     </tr>
#     <tr>
#       <th>Average positions per day</th>
#       <td>0.11</td>
#     </tr>
#     <tr>
#       <th>Average interest paid</th>
#       <td>$0.00</td>
#     </tr>
#     <tr>
#       <th>Median interest paid</th>
#       <td>$0.00</td>
#     </tr>
#     <tr>
#       <th>Total interest paid</th>
#       <td>$0.00</td>
#     </tr>
#     <tr>
#       <th><a href="https://tradingstrategy.ai/glossary/liquidity-provider">LP fees paid</a></th>
#       <td>$19,595.05</td>
#     </tr>
#     <tr>
#       <th><a href="https://tradingstrategy.ai/glossary/liquidity-provider">LP fees paid % of volume</a></th>
#       <td>0.05%</td>
#     </tr>
#     <tr>
#       <th><a href="https://tradingstrategy.ai/glossary/mean">Average position</a></th>
#       <td>1.23%</td>
#     </tr>
#     <tr>
#       <th><a href="https://tradingstrategy.ai/glossary/median">Median position</a></th>
#       <td>-0.75%</td>
#     </tr>
#     <tr>
#       <th>Most consecutive wins</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>Most consecutive losses</th>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th><a href="https://tradingstrategy.ai/glossary/realised-risk">Biggest realised risk</a></th>
#       <td>-11.04%</td>
#     </tr>
#     <tr>
#       <th><a href="https://tradingstrategy.ai/glossary/realised-risk">Avg realised risk</a></th>
#       <td>-2.37%</td>
#     </tr>
#     <tr>
#       <th><a href="https://tradingstrategy.ai/glossary/maximum-pullback">Max pullback of total capital</a></th>
#       <td>-16.90%</td>
#     </tr>
#     <tr>
#       <th>Max loss risk at opening of position</th>
#       <td>32.57%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Pair statistics

# %%
from tradeexecutor.analysis.multipair import analyse_multipair
from tradeexecutor.analysis.multipair import format_multipair_summary

multipair_summary = analyse_multipair(state)
display(format_multipair_summary(multipair_summary))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th><a href="https://tradingstrategy.ai/glossary/trading-pair">Trading pair</a></th>
#       <th><a href="https://tradingstrategy.ai/glossary/position">Positions</a></th>
#       <th><a href="https://tradingstrategy.ai/glossary/swap">Trades</a></th>
#       <th>Total PnL USD</th>
#       <th>Best</th>
#       <th>Worst</th>
#       <th>Avg</th>
#       <th>Median</th>
#       <th>Volume</th>
#       <th>Wins</th>
#       <th>Losses</th>
#       <th><a href="https://tradingstrategy.ai/glossary/take-profit">Take profits</a></th>
#       <th><a href="https://tradingstrategy.ai/glossary/stop-loss">Stop losses</a></th>
#       <th><a href="https://tradingstrategy.ai/glossary/trailing-stop-loss">Trailing stop losses</a></th>
#       <th>Volatility</th>
#       <th><a href="https://tradingstrategy.ai/glossary/aggregate-return">Total return %</a></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>ETH-USDT spot</td>
#       <td>110</td>
#       <td>309</td>
#       <td>128,703.28</td>
#       <td>25.70%</td>
#       <td>-12.17%</td>
#       <td>1.47%</td>
#       <td>-0.38%</td>
#       <td>20,344,104.85</td>
#       <td>49</td>
#       <td>49</td>
#       <td>0</td>
#       <td>42</td>
#       <td>38</td>
#       <td>6.56%</td>
#       <td>161.72%</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>BTC-USDT spot</td>
#       <td>95</td>
#       <td>291</td>
#       <td>115,180.55</td>
#       <td>20.60%</td>
#       <td>-9.95%</td>
#       <td>0.94%</td>
#       <td>-0.89%</td>
#       <td>18,836,132.49</td>
#       <td>41</td>
#       <td>41</td>
#       <td>0</td>
#       <td>29</td>
#       <td>27</td>
#       <td>5.06%</td>
#       <td>89.77%</td>
#     </tr>
#   </tbody>
# </table>
