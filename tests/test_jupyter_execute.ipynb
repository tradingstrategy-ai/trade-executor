# %%
from tradeexecutor.utils.jupyter_notebook_name import get_notebook_id

notebook_id = get_notebook_id(globals())
assert notebook_id == "test_jupyter_execute", f"Expected 'test_jupyter_execute', got '{notebook_id}'"
print(f"OK: notebook_id={notebook_id}")

# %%
from tradeexecutor.utils.cpu import get_safe_max_workers_count, is_running_in_ipython

assert not is_running_in_ipython(), "jupyter execute should NOT be detected as IPython CLI"
assert get_safe_max_workers_count() >= 1
print(f"OK: is_running_in_ipython={is_running_in_ipython()}, max_workers={get_safe_max_workers_count()}")
